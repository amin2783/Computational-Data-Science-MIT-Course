# %%
import matplotlib.pyplot as plt
import numpy as np

xs = np.linspace(-np.pi,np.pi,num=20000000)
ys = np.sin(xs)
plt.plot(xs,ys)
plt.show()

# %%
x = np.linspace(0, 100, 10000000)
y = np.linspace(0, 10, 10000000)

plt.plot(x, y)
plt.show()

# %%
import numpy as np

B = np.linspace(0, 4.9, 500)

# %%
import numpy as np

C = np.array([[1,2,3], [4,5,6]])

print('print C:')
print(C)
print('shape:', C.shape)
print()


M_1D = np.array([1,2,3,4,5,6])
M_2D = np.reshape(M_1D, (2,3))

print('print M_2D:')
print(M_2D)
print('shape:', M_2D.shape)
print('shape of M_1D:', M_1D.shape)
# Out:
# print C:
# [[1 2 3]
#  [4 5 6]]
# shape: (2, 3)
#
# print M_2D:
# [[1 2 3]
#  [4 5 6]]
# shape: (2, 3)
# shape of M_1D: (6,)

# %%
print(np.array([[1],[1],[1]]))
# Out:
# [[1]
#  [1]
#  [1]]

# %%
x31 = np.array([[1],[5],[3]])
x13 = np.array([[1,5,3]])
x3 = np.array([1,5,3])

print('x31', x31)
print(x31.shape)
print()

print('x13')
print(x13)
print()

print('x3')
print(x3)
print()

print('x13.T (should equal x31)')
print(x13.T)
print()

print('x3.T (will not equal x31)')
print(x3.T)
print()
# Out:
# x31 [[1]
#  [5]
#  [3]]
# (3, 1)
#
# x13
# [[1 5 3]]
#
# x3
# [1 5 3]
#
# x13.T (should equal x31)
# [[1]
#  [5]
#  [3]]
#
# x3.T (will not equal x31)
# [1 5 3]

# %%
x = np.array([[1, 2],[5, 3],[3, 4]])
y = np.array([1,5,3])
print(x, '\n' , x.shape)
print(y, '\n' , y.shape)
# Out:
# [[1 2]
#  [5 3]
#  [3 4]]
#  (3, 2)
# [1 5 3]
#  (3,)

# %%
a = np.array([1,2,3])
b = np.array([[4, 5, 6]])

print(a, '\n', a.shape, '\n', b, '\n', b.shape)
# Out:
# [1 2 3]
#  (3,)
#  [[4 5 6]]
#  (1, 3)

# %%
x = np.array([[1,2],[3,4],[5,6]])
print(x)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
a = np.array([[1], [2], [3]])
b = np.array([[4], [5], [6]])
# c = np.vstack((a,b))

print(a)
print()
print(a.shape)
print()
# print(c)
# Out:
# [[1]
#  [2]
#  [3]]
#
# (3, 1)

# %%
A = np.array([[5,7,10,14],[2,4,8,9]])

B = A[1,1:20]
print(B)
# Out:
# [4 8 9]
